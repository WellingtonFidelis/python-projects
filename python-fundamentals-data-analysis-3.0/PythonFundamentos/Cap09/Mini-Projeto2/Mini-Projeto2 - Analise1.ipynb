# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 9</font>
#
# ## Download: http://github.com/dsacademybr
#
# ## Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 1

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style = "white")
# %matplotlib inline

# %%
# Unzip file

if os.path.exists("./dataset/autos.csv"):
    print("File already exist.")
else:
    import zipfile
    import shutil
    
    with zipfile.ZipFile("dataset/autos.zip", "r") as zip_reference:
        zip_reference.extractall("dataset/")
        
    location = "./dataset"
    directory = "__MACOSX"
    path = os.path.join(location, directory)

    shutil.rmtree(path)
# Out:
# File already exist.

# %%
# Dataset
clean_data_path = "dataset/autos.csv"
df = pd.read_csv(clean_data_path,encoding = "latin-1")

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-23 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
# 3  2016-03-17 16:54:04             GOLF_4_1_4__3TÃRER  privat     Offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  ...  \
# 0    480   test       Other                1993    manuell        0  ...
# 1  18300   test       coupe                2011    manuell      190  ...
# 2   9800   test         suv                2004  automatik      163  ...
# 3   1500   test  kleinwagen                2001    manuell       75  ...
# 4   3600   test  kleinwagen                2008    manuell       69  ...
#
#   postalCode             lastSeen yearOfCreation yearCrawled monthOfCreation  \
# ...

# %%
# 313 867 rows and 27 columns
df.shape
# Out:
# (313687, 27)

# %% [markdown]
# ## Distribuição de Veículos com base no Ano de Registro

# %%
# Crie um Plot com a Distribuição de Veículos com base no Ano de Registro

# %%
# Salvando o plot
fig.savefig("plots/Analise1/vehicle-distribution.png")

# %%
sns.kdeplot(df.yearOfRegistration, shade=False)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.histplot(data=df.yearOfRegistration, color='blue', kde=True, ax=ax, legend=True)
ax.set_title('Distribuição de Veículos com base no Ano de Registro', fontsize=16)
plt.xlabel('Ano de registro', fontsize=16)
plt.ylabel('Densidade (KDE)', fontsize=16)
plt.show()

# %%
fig.savefig('plots/Analise1/vehicle-distribution-2.png')

# %% [markdown]
# ## Variação da faixa de preço pelo tipo de veículo

# %%
# Crie um Boxplot para avaliar os outliers

# %%
# Salvando o plot
fig.savefig("plots/Analise1/price-vehicleType-boxplot.png")

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x='vehicleType', y='price', data=df, linewidth=1.5, )
ax.set_title('Variação da faixa de preço pelo tipo de veículo', fontsize=16)
ax.text(5.25,27000, "Análise de Outliers", fontsize=18, color="r", ha="center", va="center")

plt.xlabel('Tipo de veículo', fontsize=16)
plt.ylabel('Range de preço', fontsize=16)
# ax.xaxis.set_label_text('dsadas')
plt.show()

# %%
# Salvando o plot
fig.savefig("plots/Analise1/price-vehicleType-boxplot-2.png")

# %% [markdown]
# ## Contagem total de veículos à venda conforme o tipo de veículo

# %%
# Crie um Count Plot que mostre o número de veículos pertencentes a cada categoria

# %%
# Salvando o plot
g.savefig("plots/Analise1/count-vehicleType.png")

# %%
sns.set_style(style='darkgrid')
g = sns.catplot(x='vehicleType', data=df, kind='count', palette='BuPu', height=6, aspect=1.5)
g.ax.xaxis.set_label_text('Tipo de veículo', fontdict={'size': 16})
g.ax.yaxis.set_label_text('Total de veículo para venda', fontdict={'size': 16})
g.ax.set_title('Contagem total de veículos à venda conforme o tipo de veículo', fontdict={'size': 20})
# to get the counts on the top heads of the bar
for p in g.ax.patches:
    g.ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+500))

# %%
g.savefig("plots/Analise1/count-vehicleType-2.png")

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado
#
# ### Visite o Blog da Data Science Academy - <a href="http://blog.dsacademy.com.br">Blog DSA</a>
